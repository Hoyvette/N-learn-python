# %% [markdown]
# <a href="https://colab.research.google.com/github/Hoyvette/N-learn-python/blob/main/20240329.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #2024 3 29

# %% [markdown]
# #使用Pillow做影像處理

# %% [markdown]
# ##read a image

# %%
from PIL import Image

# %%
img = Image.open('Cat Image.webp')

# %%
img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1200x800>

# %% [markdown]
# ###讀取影像 inspect property

# %%
img.size
# Out:
# (1200, 800)

# %%
img.mode
#RGB = Red Blue Green, or rainbow/ colored
# Out:
# 'RGB'

# %%
img.format
# Out:
# 'WEBP'

# %% [markdown]
# ###將彩色圖片轉成單色

# %%
img.convert('L')
#L= lumunes， brightness
# Out:
# <PIL.Image.Image image mode=L size=1200x800>

# %%
img.convert('L').save("gray.jpg")

# %% [markdown]
# ###圖形改變大小
# * resize
# * thumbnail

# %%
img.resize?
#Question mark to open 'help'

# %%
img.resize((800,500))
# Out:
# <PIL.Image.Image image mode=RGB size=800x500>

# %%
img.resize((1200//5,800//5))
# Out:
# <PIL.Image.Image image mode=RGB size=240x160>

# %%
img01 = img.copy()
#() = 執行

# %%
img01.thumbnail?

# %%
img01.thumbnail((300, 300))

# %%
img01
# Out:
# <PIL.Image.Image image mode=RGB size=200x133>

# %%
img01.thumbnail((200,200))
#boarder

# %%
img01
# Out:
# <PIL.Image.Image image mode=RGB size=200x133>

# %% [markdown]
# ###Rotate Image (Transpose)
# * Transpose
# use “img.transpose?" and search commands

# %%
img.transpose?

# %%
img01.transpose(Image.Transpose.ROTATE_270)
# Out:
# <PIL.Image.Image image mode=RGB size=133x200>

# %% [markdown]
# ####Test

# %%
from PIL import Image

# %%
cat = Image.open("Cat.jfif")

# %%
cat.size
# Out:
# (275, 183)

# %%
cat
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
cat.resize((275//2,183//2))
# Out:
# <PIL.Image.Image image mode=RGB size=137x91>

# %%
cat01 = cat.convert('L')

# %%
cat01
# Out:
# <PIL.Image.Image image mode=L size=275x183>

# %%
cat.transpose(Image.Transpose.ROTATE_180)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %% [markdown]
# ###Rotate 2.0
# *Rotate

# %%
cat.rotate(45)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
cat.rotate(45, expand=1)
# Out:
# <PIL.Image.Image image mode=RGB size=325x325>

# %%
cat.rotate(45, expand=1, fillcolor="white")
# Out:
# <PIL.Image.Image image mode=RGB size=325x325>

# %%
r, g, b = cat.split()
BLUE = Image.merge('RGB', (b, g, r))

# %% [markdown]
# ###Crop

# %%
cat
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
cat.size
# Out:
# (275, 183)

# %%
cat.crop?

# %%
cat.crop((60,15, 180, 170))
#left, up, right, down
# Out:
# <PIL.Image.Image image mode=RGB size=120x155>

# %% [markdown]
# ###Paste

# %%
cat
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
cat01
# Out:
# <PIL.Image.Image image mode=L size=275x183>

# %%
img01.paste(cat01, (50,54))

# %%
img01
# Out:
# <PIL.Image.Image image mode=RGB size=200x133>

# %%
cat.size
# Out:
# (275, 183)

# %%
cat03=Image.new("RGB", (200,105),"black")

# %%
cat03.paste(img, (0,0))

# %%
cat03
# Out:
# <PIL.Image.Image image mode=RGB size=200x105>
